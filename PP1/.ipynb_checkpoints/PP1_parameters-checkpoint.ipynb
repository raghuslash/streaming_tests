# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal
import numpy as np
import seaborn as sns

# %%
plt.rcParams["figure.figsize"]=[15,5]

# %%
merged=pd.read_csv('PP1_PCB_Merged_DataFrame.csv')
merged['arvl_tmstmp']=pd.to_datetime(merged['arvl_tmstmp'])
merged['dptr_tmstmp']=pd.to_datetime(merged['dptr_tmstmp'])

# %%
raw_pp=pd.read_csv('pickandplace1.csv', usecols=['timestamp', 'data.ax', 'data.az'])
raw_pp.sort_values(by=['timestamp'], inplace=True)
raw_pp.reset_index(inplace=True)
raw_pp.dropna(axis=0, inplace=True)
raw_pp['timestamp'] =  pd.to_datetime(raw_pp['timestamp'])

# %%
# raw_pp_current=pd.read_csv('pickandplace2.csv', usecols=['timestamp', 'data.A1', 'data.A2', 'data.A3'])
# raw_pp_current.sort_values(by=['timestamp'])
# raw_pp_current.reset_index(inplace=True)
# raw_pp_current['total_current']=raw_pp_current['data.A1']+raw_pp_current['data.A2']+raw_pp_current['data.A3']
# raw_pp_current['timestamp']=pd.to_datetime(raw_pp_current['timestamp'])
# raw_pp_current.index=raw_pp_current['timestamp']

# %%
#Load LD data and plot
raw_pp["acc"] = ( raw_pp["data.ax"]**2 + raw_pp["data.az"]**2) ** 0.5
acc=raw_pp[["timestamp", "acc"]]
test_pp=acc
# test_pp['acc_rolling_sum']=pd.Series.to_frame(test_pp.acc.rolling(100*10, center=True).sum())
# test_pp['acc_rolling_std']=pd.Series.to_frame(test_pp.acc.rolling(100*2, center=True).std())

# %%
# %matplotlib qt

# %%
raw_pp
# Out:
#          index                  timestamp   data.ax   data.az       acc
# 0         2761 2019-03-01 10:00:00.090285 -0.017822  0.019287  0.026261
# 1         2762 2019-03-01 10:00:00.091355 -0.016907  0.014099  0.022014
# 2         2763 2019-03-01 10:00:00.092360 -0.014771  0.016724  0.022313
# 3         2764 2019-03-01 10:00:00.093353 -0.015869  0.010559  0.019061
# 4         2765 2019-03-01 10:00:00.111775 -0.016724  0.012268  0.020741
# 5         2766 2019-03-01 10:00:00.112867 -0.017883  0.014160  0.022811
# 6         2767 2019-03-01 10:00:00.113872 -0.017090  0.009155  0.019388
# 7         2768 2019-03-01 10:00:00.125336 -0.016235  0.021423  0.026880
# 8         2769 2019-03-01 10:00:00.126381 -0.018677  0.024292  0.030642
# 9         2770 2019-03-01 10:00:00.127387 -0.009033  0.015869  0.018260
# 10        2771 2019-03-01 10:00:00.132776 -0.014221  0.020142  0.024656
# 11        2772 2019-03-01 10:00:00.133825 -0.015625 -0.001465  0.015694
# 12        2773 2019-03-01 10:00:00.146186 -0.003113  0.022095  0.022313
# 13        2774 2019-03-01 10:00:00.147215 -0.022827  0.018555  0.029417
# 14        2775 2019-03-01 10:00:00.151278 -0.023926  0.028870  0.037495
# 15        2776 2019-03-01 10:00:00.152334 -0.009705 -0.007080  0.012013
# 16        2777 2019-03-01 10:00:00.153347 -0.018921  0.035461  0.040193
# 17        2778 2019-03-01 10:00:00.154363 -0.011902  0.041016  0.042708
# 18        2779 2019-03-01 10:00:00.165892 -0.020325  0.009338  0.022367
# 19        2780 2019-03-01 10:00:00.166968 -0.010986  0.019897  0.022729
# 20        2781 2019-03-01 10:00:00.168098 -0.019836 -0.003601  0.020161
# 21        2782 2019-03-01 10:00:00.169140 -0.013306  0.006042  0.014613
# 43 2019-03-01 10:47:35.513329            1  47.287235    0.000000   1.896986
# 44 2019-03-01 10:48:03.562330            2  23.686827    2.268735   0.917808
# 45 2019-03-01 10:48:33.487470            1  20.536071    0.000000   0.824110
# 46 2019-03-01 10:49:49.638410            1  74.706822    0.000000   2.977534
# 47 2019-03-01 10:50:19.391881            1  20.498135    0.000000   0.819726
# 48 2019-03-01 10:51:08.748444            1  47.342216    0.000000   1.905205
# 49 2019-03-01 10:51:35.430700            1  24.737231    0.000000   0.999452
# 50 2019-03-01 10:53:21.339450            1  96.680444    0.000000   3.887123
# 51 2019-03-01 10:53:50.927631            1  20.538940    0.000000   0.825753
# 52 2019-03-01 10:54:40.164542            1  47.187392    0.000000   1.893699
# 53 2019-03-01 10:55:06.843208            1  24.646717    0.000000   0.987397
# 54 2019-03-01 10:56:25.910798            1  69.845381    0.000000   2.785753
# 55 2019-03-01 10:56:52.702868            1  25.398341    0.000000   0.990137
# 56 2019-03-01 10:57:21.576419            1  20.370321    0.000000   0.825205
# 57 2019-03-01 10:58:10.950373            1  47.221757    0.000000   1.887123
# 58 2019-03-01 10:58:37.576426            1  24.567289    0.000000   0.983014
# 59 2019-03-01 10:59:07.427421            1  20.647291    0.000000   0.829041
# 60 2019-03-01 10:59:56.280796            1  46.745718    0.000000   1.873973
#
# [61 rows x 9 columns]

# %%
plt.plot(test_pp['timestamp'], test_pp['acc'], 'orange')
plt.stem(merged['arvl_tmstmp'], np.ones(merged.shape[0])*0.5, 'g')
plt.stem(merged['dptr_tmstmp'], np.ones(merged.shape[0])*0.5, 'r')
# Out:
# <StemContainer object of 3 artists>

# %%
test_pp['detections']=pd.Series.to_frame(test_pp.acc_rolling_std.rolling(100, center=True).sum())

# %%
plt.plot(test_pp['timestamp'], test_pp['acc']*100)
plt.plot(test_pp['timestamp'], test_pp['detections'])

# %%
# plt.plot(test_pp['timestamp'], test_pp['detections'])

# %%
test_pp['boards']=0
test_pp['boards'][test_pp['detections']>=2]=1

# %%
plt.plot(test_pp['timestamp'], test_pp['acc']*100)
plt.plot(test_pp["timestamp"],test_pp["boards"])

# %%
working_times_raw=scipy.signal.find_peaks(test_pp.boards, width=1)

# %%
working_times_raw_df=pd.DataFrame({"sample_number":working_times_raw[0], "working_time":working_times_raw[1]['widths']/72})

# %%
test_pp['boards']=test_pp['boards']*-1
idle_times_raw=scipy.signal.find_peaks(test_pp.boards, width=1)
idle_times_raw_df=pd.DataFrame({"sample_number":idle_times_raw[0], "working_time":idle_times_raw[1]['widths']/72})
test_pp['boards']=test_pp['boards']*-1

# %%
for x, row in working_times_raw_df.iterrows():
    working_times_raw_df.ix[x,'start_time']=test_pp.iloc[int(working_times_raw[1]['left_ips'][x])].timestamp
    working_times_raw_df.ix[x,'end_time']=test_pp.iloc[int(working_times_raw[1]['right_ips'][x])].timestamp
    working_times_raw_df.ix[x,'timestamp']=test_pp.iloc[int(working_times_raw[0][x])].timestamp

# %%
for x, row in idle_times_raw_df.iterrows():
    idle_times_raw_df.ix[x,'start_time']=test_pp.iloc[int(idle_times_raw[1]['left_ips'][x])].timestamp
    idle_times_raw_df.ix[x,'end_time']=test_pp.iloc[int(idle_times_raw[1]['right_ips'][x])].timestamp
    idle_times_raw_df.ix[x,'timestamp']=test_pp.iloc[int(idle_times_raw[0][x])].timestamp

# %%
working_times_df=working_times_raw_df[working_times_raw_df.working_time>10]

# %%
working_times_df['event']=1
idle_times_raw_df['event']=0

# %%
# working_times_df['energy']=raw_pp_current[(raw_pp_current['timestamp'] <= working_times_df['end_time']) & (raw_pp_current['timestamp'] >= working_times_df['start_time'])]['total_current'].sum()*230

# %%
working_times_df['energy'] = working_times_df.apply(lambda x: raw_pp_current.loc[(raw_pp_current.timestamp <= x.end_time) & 
                                                            (x.start_time <= raw_pp_current.timestamp),
                                                            ['total_current']].sum()*230/3600000, axis=1)

# %%
# for index, x in enumerate(working_times_raw[0]):
#     working_times_raw_df.ix[index,'energy']=np.trapz(raw_pp_current.ix[int(working_times_raw[1]['left_ips'][index]):int(working_times_raw[1]['right_ips'][index]), 'data.A1'].tolist())
# working_times_raw_df['energy']=working_times_raw_df['energy']*230/3600000

# %%
idle_times_raw_df['energy'] = idle_times_raw_df.apply(lambda x: raw_pp_current.loc[(raw_pp_current.timestamp <= x.end_time) & 
                                                            (x.start_time <= raw_pp_current.timestamp),
                                                            ['total_current']].sum()*230/3600000, axis=1)

# %%
# for index, x in enumerate(idle_times_raw[0]):
#     idle_times_raw_df.ix[index,'energy']=np.trapz(raw_pp_current.ix[int(idle_times_raw[1]['left_ips'][index]):int(idle_times_raw[1]['right_ips'][index]), 'data.A1'].tolist(), dx=1)
# idle_times_raw_df['energy']=idle_times_raw_df['energy']*230/3600000

# %%
working_times_df.index=working_times_df.timestamp
working_times_df.drop('timestamp', axis=1, inplace=True)
# working_times_df.drop('sample_number', axis=1, inplace=True)

# %%
idle_times_raw_df.index=idle_times_raw_df.timestamp
idle_times_raw_df.drop('timestamp', axis=1, inplace=True)
# idle_times_raw_df.drop('sample_number', axis=1, inplace=True)

# %%
# plt.plot(test_pp["timestamp"],test_pp["boards"])
# plt.plot(raw_pp_current.timestamp, raw_pp_current['total_current'])

# %%
PP_events=working_times_df[['event', 'working_time', 'energy']]

# %%
idle_times_df=idle_times_raw_df[['event', 'working_time', 'energy']]
PP_events=PP_events.append(idle_times_df)

# %%
# sns.distplot(PP_events[PP_events.event==1].working_time)
# plt.title('PP1 Working Times Histogram')

# %%
# print('PP working time mode: ', PP_events[PP_events.event==1].working_time.mode().mean())

# %%
# sum(raw_pp_current.total_current.tolist())

# %%
# PP_events.loc[PP_events.event==0, 'energy']

# %%
plt.plot(test_pp.timestamp, test_pp.acc)

# %%
PP_events.sort_values(by=['timestamp'], inplace=True)

# %%
# plt.plot(PP_events.index, PP_events.event)
plt.plot(test_pp["timestamp"],test_pp["boards"])

# %%
# PP_events[PP_events.event==0]

# %%
# plt.plot(raw_pp_current.timestamp,raw_pp_current.total_current)

# %%
plt.stem(idle_times_df.index, idle_times_df.event)

# %%
# sns.distplot(idle_times_df.power)

# %%
# working_times_df['power']=working_times_df['energy']*3600000/working_times_df['working_time']

# %%
#sns.distplot(PP_events[PP_events.event==1].working_time, bins=50)

# %%
PPdist=PP_events[PP_events.event==1]

# %%
PPdist

# %%
PPdist=PPdist[PPdist.working_time < np.percentile(PPdist.working_time,95)]

# %%
print(PPdist.working_time.max())
print(PPdist.working_time.min())

# %%
binnum=int(round((PPdist.working_time.max()-PPdist.working_time.min())/5))
binnum

# %%
sns.distplot(PP_events[PP_events.event==1].working_time, bins=binnum)

# %%
modeWT=pd.cut(PPdist[PPdist.event==1]["working_time"], bins=binnum).value_counts().idxmax().mid

# %%
modeWT

# %%
test_pp['event']=0
for index, row in working_times_df.iterrows():
#     test_pp2.ix[int(row.left_ips):int(row.right_ips), 'event']=1
    test_pp.loc[(test_pp.timestamp <= row.end_time) & (row.start_time <= test_pp.timestamp), ['event']]=1

# %%
# statistics.mode(PP_events[PP_events.event==1].working_time.tolist(), bins=10)

# %%
plt.plot(test_pp.timestamp, test_pp.acc)
plt.plot(test_pp.timestamp, test_pp.event*0.3)

# %%
PP_events

# %%
PP_boardevents=PP_events[PP_events.event==1]

# %%
tempdf=PP_boardevents[1:1]
tempdf['nmodes']=0
flagsdf=PP_boardevents[1:1]
flagsdf['flagid']=0

# %%
# import dill
# dill.dump_session('modeTest.db')

# %%
import dill
dill.load_session('modeTest.db')

# %%
# PP_boardevents

# %%
for i, row in PP_boardevents.iterrows():
    nmodes=row.working_time/modeWT
    frac=nmodes%1
    nmodes=np.floor(nmodes)
    if (1-frac) <= .15:
        nmodes=np.floor(nmodes)+1
    
    elif (not (frac <= .15)) or nmodes==0.0:
        tseries=row
        tseries=tseries.append(pd.Series([1], index=['flagid']))
        flagsdf=flagsdf.append(tseries, ignore_index=True)
        continue
    
    if nmodes==1.0:
        continue
        
    tseries=row
    tseries=tseries.append(pd.Series([nmodes], index=['nmodes']))
    tempdf=tempdf.append(tseries, ignore_index=True)
    PP_boardevents.drop(i, inplace=True)

# %%
# plt.stem(tempdf.index, tempdf.event)

# %%
tempdf

# %%
# flagsdf

# %%
# PP_boardevents=PP_boardevents.reset_index()
PP_boardeventsSplit=PP_boardevents
PP_boardevents.reset_index()

# %%
for i, row in tempdf.iterrows():
    nmodes=int(row.nmodes)
    wt=row.working_time/nmodes
    en=row.energy/nmodes
    if nmodes%2==0:
        for n in range(0, int(nmodes/2)):
            ts1=row.timestamp-pd.to_timedelta(0.5*(2*n+1)*wt, unit='s')
            ts2=row.timestamp+pd.to_timedelta(0.5*(2*n+1)*wt, unit='s')
            print(n)
            PP_boardeventsSplit=PP_boardeventsSplit.append({"timestamp":ts1, "event":1, "working_time":wt, "energy":en}, ignore_index=True)
            PP_boardeventsSplit=PP_boardeventsSplit.append({"timestamp":ts2, "event":1, "working_time":wt, "energy":en}, ignore_index=True)
    else:
        PP_boardevents=PP_boardeventsSplit.append({"timestamp":row.timestamp, "event":1, "working_time":wt, "energy":en}, ignore_index==True)
        for n in range(0, int(nmodes/2)):
            ts1=row.timestamp-pd.to_timedelta(0.5*(2*n+2)*wt, unit='s')
            ts2=row.timestamp+pd.to_timedelta(0.5*(2*n+2)*wt, unit='s')
            PP_boardeventsSplit=PP_boardeventsSplit.append({"timestamp":ts1, "event":1, "working_time":wt, "energy":en}, ignore_index=True)
            PP_boardeventsSplit=PP_boardeventsSplit.append({"timestamp":ts2, "event":1, "working_time":wt, "energy":en}, ignore_index=True)

# %%
PP_boardeventsSplit

# %%
plt.plot(test_pp.timestamp, test_pp.acc)
plt.plot(test_pp.timestamp, test_pp.event*0.3)

# %%
plt.stem(PP_boardeventsSplit.timestamp, PP_boardeventsSplit.event*0.6)
